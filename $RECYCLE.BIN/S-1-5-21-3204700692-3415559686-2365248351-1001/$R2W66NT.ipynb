# %%
#install yahoo finance package

# pip install yfinance

# pip install pandas_datareader

# %%
# import yahoo finance package to get stock data


import yfinance as yf

# %%
# Required python libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load Microsoft Stock Price data for last month

data = yf.download('MSFT', start="2021-01-01", end="2022-11-30")
data.to_csv('MSFT.csv')

df = pd.read_csv('MSFT.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# import pandas_datareader as pdr

# import pandas_datareader.data as web

# msft = web.DataReader('MSFT', data_source='yahoo', start='2015-01-01', end='2020-06-30')

# msft.to_csv('MSFT.csv')

# %%
# Load first five rows


df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-01-04  222.529999  223.000000  214.809998  217.690002  213.876358
# 1  2021-01-05  217.259995  218.520004  215.699997  217.899994  214.082687
# 2  2021-01-06  212.169998  216.490005  211.940002  212.250000  208.531662
# 3  2021-01-07  214.039993  219.339996  213.710007  218.289993  214.465881
# 4  2021-01-08  218.679993  220.580002  217.029999  219.619995  215.772552
#
#      Volume
# 0  37130100
# 1  23823000
# 2  35930700
# 3  27694500
# 4  22956200

# %%
# load last five rows

df.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 476  2022-11-22  243.589996  245.309998  240.710007  245.029999  245.029999
# 477  2022-11-23  245.110001  248.279999  244.270004  247.580002  247.580002
# 478  2022-11-25  247.309998  248.699997  246.729996  247.490005  247.490005
# 479  2022-11-28  246.080002  246.649994  240.800003  241.759995  241.759995
# 480  2022-11-29  241.399994  242.789993  238.210007  240.330002  240.330002
#
#        Volume
# 476  19665700
# 477  19508500
# 478   9200800
# 479  24778200
# 480  17956300

# %%
# to display whole dataset

# print(df.to_string())

# %%
# def split_date():
#     return str.split('-')
list1 = []
for i in df.index.values:
    a = str(i).split('-')
    list1.append(a)
    break
list1
# Out:
# [['0']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       481 non-null    object
#  1   Open       481 non-null    float64
#  2   High       481 non-null    float64
#  3   Low        481 non-null    float64
#  4   Close      481 non-null    float64
#  5   Adj Close  481 non-null    float64
#  6   Volume     481 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 26.4+ KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  481.000000  481.000000  481.000000  481.000000  481.000000
# mean   273.619272  276.470769  270.602578  273.641642  271.065624
# std     32.280915   32.272327   31.945080   32.198589   31.976699
# min    212.169998  214.509995  211.940002  212.250000  208.531662
# 25%    245.979996  248.699997  244.020004  246.789993  244.078705
# 50%    270.690002  273.750000  267.980011  271.399994  268.690857
# 75%    297.549988  300.220001  294.070007  296.989990  293.955597
# max    344.619995  349.670013  342.200012  343.109985  339.924805
#
#              Volume
# count  4.810000e+02
# mean   2.859122e+07
# std    1.001363e+07
# min    9.200800e+06
# 25%    2.218670e+07
# 50%    2.645800e+07
# 75%    3.316920e+07
# max    9.042890e+07

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
dr1 = pd.date_range(start='2022-11-01', end='2022-11-30')
dr1
# Out:
# DatetimeIndex(['2022-11-01', '2022-11-02', '2022-11-03', '2022-11-04',
#                '2022-11-05', '2022-11-06', '2022-11-07', '2022-11-08',
#                '2022-11-09', '2022-11-10', '2022-11-11', '2022-11-12',
#                '2022-11-13', '2022-11-14', '2022-11-15', '2022-11-16',
#                '2022-11-17', '2022-11-18', '2022-11-19', '2022-11-20',
#                '2022-11-21', '2022-11-22', '2022-11-23', '2022-11-24',
#                '2022-11-25', '2022-11-26', '2022-11-27', '2022-11-28',
#                '2022-11-29', '2022-11-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
df['Date'] = pd.to_datetime(df.Date,format='%Y/%m/%d')
df.index = df['Date']
plt.figure(figsize=(10,7))
plt.plot(df['Close'], label='Close Price history',color='b')
plt.xlabel('Date',size=20)
plt.ylabel('Stock Price',size=20)
plt.title('Stock Price of Microsoft over the Years',size=25)
# Out:
# Text(0.5, 1.0, 'Stock Price of Microsoft over the Years')

# %%
df['year'] = df['Date'].dt.year
df['year']
# Out:
# Date
# 2021-01-04    2021
# 2021-01-05    2021
# 2021-01-06    2021
# 2021-01-07    2021
# 2021-01-08    2021
#               ...
# 2022-11-22    2022
# 2022-11-23    2022
# 2022-11-25    2022
# 2022-11-28    2022
# 2022-11-29    2022
# Name: year, Length: 481, dtype: int64

# %%
df
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2021-01-04 2021-01-04  222.529999  223.000000  214.809998  217.690002
# 2021-01-05 2021-01-05  217.259995  218.520004  215.699997  217.899994
# 2021-01-06 2021-01-06  212.169998  216.490005  211.940002  212.250000
# 2021-01-07 2021-01-07  214.039993  219.339996  213.710007  218.289993
# 2021-01-08 2021-01-08  218.679993  220.580002  217.029999  219.619995
# ...               ...         ...         ...         ...         ...
# 2022-11-22 2022-11-22  243.589996  245.309998  240.710007  245.029999
# 2022-11-23 2022-11-23  245.110001  248.279999  244.270004  247.580002
# 2022-11-25 2022-11-25  247.309998  248.699997  246.729996  247.490005
# 2022-11-28 2022-11-28  246.080002  246.649994  240.800003  241.759995
# 2022-11-29 2022-11-29  241.399994  242.789993  238.210007  240.330002
#
#              Adj Close    Volume  year
# Date
# 2021-01-04  213.876358  37130100  2021
# ...

# %%
df['month'] = df['Date'].dt.month
df
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2021-01-04 2021-01-04  222.529999  223.000000  214.809998  217.690002
# 2021-01-05 2021-01-05  217.259995  218.520004  215.699997  217.899994
# 2021-01-06 2021-01-06  212.169998  216.490005  211.940002  212.250000
# 2021-01-07 2021-01-07  214.039993  219.339996  213.710007  218.289993
# 2021-01-08 2021-01-08  218.679993  220.580002  217.029999  219.619995
# ...               ...         ...         ...         ...         ...
# 2022-11-22 2022-11-22  243.589996  245.309998  240.710007  245.029999
# 2022-11-23 2022-11-23  245.110001  248.279999  244.270004  247.580002
# 2022-11-25 2022-11-25  247.309998  248.699997  246.729996  247.490005
# 2022-11-28 2022-11-28  246.080002  246.649994  240.800003  241.759995
# 2022-11-29 2022-11-29  241.399994  242.789993  238.210007  240.330002
#
#              Adj Close    Volume  year  month
# Date
# 2021-01-04  213.876358  37130100  2021      1
# ...

# %%
df['day'] = df['Date'].dt.day
df
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2021-01-04 2021-01-04  222.529999  223.000000  214.809998  217.690002
# 2021-01-05 2021-01-05  217.259995  218.520004  215.699997  217.899994
# 2021-01-06 2021-01-06  212.169998  216.490005  211.940002  212.250000
# 2021-01-07 2021-01-07  214.039993  219.339996  213.710007  218.289993
# 2021-01-08 2021-01-08  218.679993  220.580002  217.029999  219.619995
# ...               ...         ...         ...         ...         ...
# 2022-11-22 2022-11-22  243.589996  245.309998  240.710007  245.029999
# 2022-11-23 2022-11-23  245.110001  248.279999  244.270004  247.580002
# 2022-11-25 2022-11-25  247.309998  248.699997  246.729996  247.490005
# 2022-11-28 2022-11-28  246.080002  246.649994  240.800003  241.759995
# 2022-11-29 2022-11-29  241.399994  242.789993  238.210007  240.330002
#
#              Adj Close    Volume  year  month  day
# Date
# 2021-01-04  213.876358  37130100  2021      1    4
# ...

# %%
x_axis = df[(df['month'] == 1)&(df["year"]==2021)]["month"]
y_axis = df[(df['month'] == 1)&(df["year"]==2021)]["Close"]

plt.plot(y_axis)
plt.title('title name')
plt.xlabel('x_axis name')
plt.ylabel('y_axis name')
plt.show()

# %%
month1 = df['Close'].head(19)
plt.plot(month1)
plt.title('title name')
plt.xlabel('x_axis name')
plt.ylabel('y_axis name')
plt.show()

# %%
# line chart for first six months

y_axis = df[(df['month'] <= 6)& (df["year"]==2021)]["Close"]

plt.plot(y_axis)
plt.title('title name')
plt.xlabel('x_axis name')
plt.ylabel('y_axis name')
plt.show()
# Out:
# Date
# 2021-01-04    217.690002
# 2021-01-05    217.899994
# 2021-01-06    212.250000
# 2021-01-07    218.289993
# 2021-01-08    219.619995
#                  ...
# 2021-06-24    266.690002
# 2021-06-25    265.019989
# 2021-06-28    268.720001
# 2021-06-29    271.399994
# 2021-06-30    270.899994
# Name: Close, Length: 124, dtype: float64

# %%
y_axis = df[(df["year"]==2021)]["Close"]

plt.plot(y_axis)
plt.title('title name')
plt.xlabel('x_axis name')
plt.ylabel('y_axis name')
plt.show()

# %%
import plotly.graph_objects as go

import pandas as pd
from datetime import datetime

fig = go.Figure(data=[go.Candlestick(x=df['Date'],open=df['Open'],high=df['High'],low=df['Low'],close=df['Close'])])

fig.show()
# Out:
# <div>                            <div id="1ca7001e-a596-442b-8b79-9822029a4f24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ca7001e-a596-442b-8b79-9822029a4f24")) {                    Plotly.newPlot(                        "1ca7001e-a596-442b-8b79-9822029a4f24",                        [{"close":[217.69000244140625,217.8999938964844,212.25,218.2899932861328,219.6199951171875,217.4900054931641,214.92999267578125,216.33999633789065,213.0200042724609,212.6499938964844,216.44000244140625,224.33999633789065,224.97000122070312,225.9499969482422,229.52999877929688,232.3300018310547,232.8999938964844,238.92999267578125,231.9600067138672,239.6499938964844,239.50999450683597,243.0,242.00999450683597,242.1999969482422,242.47000122070312,243.7700042724609,2
# ...

# %%
from datetime import datetime
# dates = np.array([datetime.datetime(2021, 1, i+1) for i in range(31)]

fig = go.Figure(data=[go.Candlestick(x=df[(df['month'] == 1)&(df["year"]==2021)]["month"],open=df['Open'],high=df['High'],low=df['Low'],close=df['Close'])])

fig.show()
# Out:
# <div>                            <div id="0678e90e-c683-4697-8bc0-b5df26075174" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0678e90e-c683-4697-8bc0-b5df26075174")) {                    Plotly.newPlot(                        "0678e90e-c683-4697-8bc0-b5df26075174",                        [{"close":[217.69000244140625,217.8999938964844,212.25,218.2899932861328,219.6199951171875,217.4900054931641,214.92999267578125,216.33999633789065,213.0200042724609,212.6499938964844,216.44000244140625,224.33999633789065,224.97000122070312,225.9499969482422,229.52999877929688,232.3300018310547,232.8999938964844,238.92999267578125,231.9600067138672,239.6499938964844,239.50999450683597,243.0,242.00999450683597,242.1999969482422,242.47000122070312,243.7700042724609,2
# ...

# %%
from datetime import datetime
# dates = np.array([datetime.datetime(2021, 1, i+1) for i in range(31)]

fig = go.Figure(data=[go.Candlestick(x=df[(df['month'] <= 6)& (df["year"]==2021)]["Close"],open=df['Open'],high=df['High'],low=df['Low'],close=df['Close'])])

fig.show()
# Out:
# <div>                            <div id="21cb6441-aad2-42ed-81e1-e6a46235f43e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21cb6441-aad2-42ed-81e1-e6a46235f43e")) {                    Plotly.newPlot(                        "21cb6441-aad2-42ed-81e1-e6a46235f43e",                        [{"close":[217.69000244140625,217.8999938964844,212.25,218.2899932861328,219.6199951171875,217.4900054931641,214.92999267578125,216.33999633789065,213.0200042724609,212.6499938964844,216.44000244140625,224.33999633789065,224.97000122070312,225.9499969482422,229.52999877929688,232.3300018310547,232.8999938964844,238.92999267578125,231.9600067138672,239.6499938964844,239.50999450683597,243.0,242.00999450683597,242.1999969482422,242.47000122070312,243.7700042724609,2
# ...

# %%
from datetime import datetime


fig = go.Figure(data=[go.Candlestick(x=df[(df["year"]==2021)],open=df['Open'],high=df['High'],low=df['Low'],close=df['Close'])])

fig.show()
# Out:
# <div>                            <div id="7c348359-0ce5-40dd-b9b9-38c13a50e69c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c348359-0ce5-40dd-b9b9-38c13a50e69c")) {                    Plotly.newPlot(                        "7c348359-0ce5-40dd-b9b9-38c13a50e69c",                        [{"close":[217.69000244140625,217.8999938964844,212.25,218.2899932861328,219.6199951171875,217.4900054931641,214.92999267578125,216.33999633789065,213.0200042724609,212.6499938964844,216.44000244140625,224.33999633789065,224.97000122070312,225.9499969482422,229.52999877929688,232.3300018310547,232.8999938964844,238.92999267578125,231.9600067138672,239.6499938964844,239.50999450683597,243.0,242.00999450683597,242.1999969482422,242.47000122070312,243.7700042724609,2
# ...
